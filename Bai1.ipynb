# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dfsalaries = pd.read_csv('T Salary Survey EU 2019.csv', sep=',')
dfsalaries
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 0    02.12.2019 11:18:26  33.0   Male     Berlin          Senior
# 1    02.12.2019 11:18:35  29.0   Male     Berlin          Middle
# 2    02.12.2019 11:18:56   NaN   Male     Berlin          Middle
# 3    02.12.2019 11:19:08  30.0   Male     Berlin          Senior
# 4    02.12.2019 11:19:37  32.0   Male     Berlin          Senior
# ..                   ...   ...    ...        ...             ...
# 985  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 986  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 987  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 988  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 989  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 0            Fullstack Developer                   13
# 1              Backend Developer                    3
# 2               Mobile Developer                    4
# 3              Backend Developer                    6
# 4             Embedded Developer                   10
# ..                           ...                  ...
# 985            Backend Developer                   10
# 986            Security Engineer                    7
# 987                      Manager                    9
# 988           Software Architect                   15
# 989          Fullstack Developer                    5
#
#     Your main technology / programming language  \
# 0                                           PHP
# 1                                        Python
# 2                                        Kotlin
# 3                                           PHP
# 4                                         C/C++
# ..                                          ...
# 985                                      Python
# 986                                Not Relevant
# 987                                Not Relevant
# 988                     Javascript / Typescript
# 989                                        Java
#
#      Yearly brutto salary (without bonus and stocks)  Yearly bonus  ...  \
# 0                                            64000.0        1000.0  ...
# 1                                            55000.0           NaN  ...
# 2                                            70000.0           NaN  ...
# 3                                            63000.0           NaN  ...
# 4                                            66000.0           NaN  ...
# ..                                               ...           ...  ...
# 985                                          71000.0        3000.0  ...
# 986                                          72000.0           0.0  ...
# 987                                          68000.0       10000.0  ...
# 988                                         100000.0        3000.0  ...
# 989                                          63000.0           NaN  ...
#
#      Yearly stocks one year ago. Only answer if staying in same country  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 985                                                0.0
# 986                                                0.0
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
#
#      Number of vacation days  Number of home office days per month  \
# 0                       29.0                                   4.0
# 1                       22.0                                   4.0
# 2                       27.0                                   NaN
# 3                       24.0                                   NaN
# 4                       30.0                                   0.0
# ..                       ...                                   ...
# 985                     25.0                                   5.0
# 986                     27.0                                   5.0
# 987                     30.0                                   5.0
# 988                     26.0                                   6.0
# 989                     30.0                                   5.0
#
#      Main language at work  Company name   Company size         Company type  \
# 0                  English            NaN        50-100              Startup
# 1                  English            NaN         10-50              Product
# 2                  English            NaN         1000+              Startup
# 3                  English          Auto1      100-1000              Product
# 4                  English         Luxoft        50-100              Product
# ..                     ...            ...           ...                  ...
# 985                English            NaN         1000+              Product
# 986                English            ING         1000+                 Bank
# 987                English            SAP         1000+              Product
# 988                English            NaN         1000+              Product
# 989                Deutsch            NaN         1000+  Consulting / Agency
#
#     Сontract duration Company business sector   0
# 0           unlimited                 Tourism NaN
# 1           unlimited   Scientific Activities NaN
# 2           unlimited                     NaN NaN
# 3           unlimited               Transport NaN
# 4           unlimited              Automotive NaN
# ..                ...                     ...  ..
# 985         unlimited                 Telecom NaN
# 986         unlimited     Finance / Insurance NaN
# 987         unlimited                Сommerce NaN
# 988  more than 1 year                  Health NaN
# 989         unlimited               Transport NaN
#
# [990 rows x 23 columns]

# %%
dfsalaries = dfsalaries.drop(columns = ['Yearly bonus','Yearly stocks','Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country','Yearly bonus one year ago. Only answer if staying in same country','Yearly stocks one year ago. Only answer if staying in same country','Number of vacation days','Number of home office days per month','Main language at work','Сontract duration','0'])
dfsalaries.rename(columns = {'Your main technology / programming language': 'Main technology' , 'Company name ':'Company name' ,'Position (without seniority)' : 'Position'}, inplace = True)
dfsalaries['Company name'] = dfsalaries['Company name'].fillna('NotFill')
dfsalaries
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 0    02.12.2019 11:18:26  33.0   Male     Berlin          Senior
# 1    02.12.2019 11:18:35  29.0   Male     Berlin          Middle
# 2    02.12.2019 11:18:56   NaN   Male     Berlin          Middle
# 3    02.12.2019 11:19:08  30.0   Male     Berlin          Senior
# 4    02.12.2019 11:19:37  32.0   Male     Berlin          Senior
# ..                   ...   ...    ...        ...             ...
# 985  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 986  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 987  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 988  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 989  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#                 Position  Years of experience          Main technology  \
# 0    Fullstack Developer                   13                      PHP
# 1      Backend Developer                    3                   Python
# 2       Mobile Developer                    4                   Kotlin
# 3      Backend Developer                    6                      PHP
# 4     Embedded Developer                   10                    C/C++
# ..                   ...                  ...                      ...
# 985    Backend Developer                   10                   Python
# 986    Security Engineer                    7             Not Relevant
# 987              Manager                    9             Not Relevant
# 988   Software Architect                   15  Javascript / Typescript
# 989  Fullstack Developer                    5                     Java
#
#      Yearly brutto salary (without bonus and stocks) Company name  \
# 0                                            64000.0      NotFill
# 1                                            55000.0      NotFill
# 2                                            70000.0      NotFill
# 3                                            63000.0        Auto1
# 4                                            66000.0       Luxoft
# ..                                               ...          ...
# 985                                          71000.0      NotFill
# 986                                          72000.0          ING
# 987                                          68000.0          SAP
# 988                                         100000.0      NotFill
# 989                                          63000.0      NotFill
#
#     Company size         Company type Company business sector
# 0         50-100              Startup                 Tourism
# 1          10-50              Product   Scientific Activities
# 2          1000+              Startup                     NaN
# 3       100-1000              Product               Transport
# 4         50-100              Product              Automotive
# ..           ...                  ...                     ...
# 985        1000+              Product                 Telecom
# 986        1000+                 Bank     Finance / Insurance
# 987        1000+              Product                Сommerce
# 988        1000+              Product                  Health
# 989        1000+  Consulting / Agency               Transport
#
# [990 rows x 13 columns]

# %%
fig = plt.figure(figsize= (15, 8))
plt.title('The distribution of the values:', fontsize= 16)
axs = fig.subplots(nrows=2, ncols= 2)
sns.boxplot(data = dfsalaries, x= 'Age', ax = axs[0,0])
sns.boxplot(data = dfsalaries, x= 'Years of experience',ax = axs[0,1])
sns.boxplot(data = dfsalaries, x= 'Yearly brutto salary (without bonus and stocks)',ax = axs[1,0])
plt.show()

# %%
x = dfsalaries['Current Salary'].astype(float)
x_mean = np.mean(x)
plt.hist(x, bins=10)
plt.show()

# %%
#bootstrap
my_samples = []
for _ in range(5000):
    x = np.random.choice(dfsalaries['Current Salary'], size=300, replace=True)
    my_samples.append(x.mean())
print(x)
# print(len(my_samples))
# sample_mean = np.mean(my_samples)
plt.hist(my_samples, bins=10)
plt.show()
# Out:
# [ 55000.  13000.  60000.  65000.  78000.  80000.  64000.  95000.  73000.
#   57000.  30000.  74000.  85000.  54000.  70000.  69600. 113000. 103000.
#   78000.  65000. 102000.  45000.  46000.  65000.  66000.  68000.  13000.
#   70000.  68000.  90000.  40000.  72000.  52000.  55000.  55000.  75000.
#   65000.  60000.  60000.  75000.  72000.  40000.  60000.     nan  80000.
#   87975. 120000.  70000.  85000.  78000.  44000.  60000.  75000.  60000.
#   49000.  86000.  53600.  40000.  85000.  66000.  68000.  35000.  58000.
#  128000.  72000.  60000.  67000.  73000.  70000.  60000. 100000.     nan
#   65000.  39600.  70000.  72000.  60000. 100000.  50000.  62000.  55000.
#   94500.     nan  60000.  80000.  15000.  58000.  48000.  55000.  60000.
#   70000.  60000.  33000.  86000.  60000.  75000. 120000. 132250.  50000.
#   75000.  83000.  54000.  80000.  87000.  95000.  66000.  75000.  85000.
#   49000.  60000.  75000.  53000.  38400.  48000.  53600.  70000.     nan
#   68000. 180000.  69000.  57000.  75000.  96000.  95000.  75000.  75000.
#  132250.  90000.  70000.  60000.  70000.  57000. 100000.  72000.  70000.
#   87500.  53600.  71000.  62000.  58000.  87000.  47000.  68000.  65000.
#   19200.  54000.  78000.  57800.  85000.  68000. 110000.  70000.  55000.
#   76000.  92100.  75000.  36000.  53000.  75000.  70000.  87000.  55000.
#   47000.  65000.  60000.  60000. 110000.  54000.  62000.  56000.  50000.
#   80000.  67000.  80000.  75000.  65000.  46000.  47000.  37000.  60000.
#   60000.  54000.  55000.  44000.  78000.  65000.  42000.  83200.  55000.
#   56000.  65000.  58000.  48000.  71000.  60000.  65000.  78000.  77000.
#   64000.  55000.  92000. 120000.  55000.  71500.  75000.  75000. 111000.
#   78000.  72000.  62000.  84000.  83200.  47250.  69000.  70000.  73000.
#   78000.  96000.  70000.  68000.  52000.  33600.  60000.  68000.  66000.
#   40800.  68000.  90000. 100000.  78000.  94500.  65000.  65000.  58000.
#   60000.  50000.  32000.  70000.  68000. 140000.  72000.  60000.  50000.
#   60000.  72000.  70000.  50000.  85000.  74000.  67000.  65000.  70000.
#   60000.  58000.  60000.  39600.  67000.  32000. 109000.  65000.  66000.
#   70000. 100000.  48000.  65000.  60000.  70000.  68000. 130000.  55000.
#   60000.  60000.  65000.  65000.  60000.  87975.  60000.  38000.  61000.
#   60000.  87000.  95000.  60000.  90000.  60000.  72000.  63000.  55000.
#   75000.  90000.  65000.  61000.  68000.  72000.  75000.  62000.  67000.
#   60000.  78000.  85000.]

# %%
# https://www.statology.org/interquartile-range-python/
q3, q1 = np.percentile(my_samples, [75, 25])
iqr = q3 - q1
iqr
# Out:
# nan
